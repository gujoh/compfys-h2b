# %%
import numpy as np
import numpy.typing as npt
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("../data/data_n100000_neq5000_alpha_0.100.csv", delimiter=",")

# %%
r_1 = data[:,:3]
r_2 = data[:,3:6]
alpha = data[:,6]
energy = data[:,7]

r1_norm = np.linalg.norm(r_1,axis=1).reshape(-1,1)
norm_r1 = r_1/r1_norm

r2_norm = np.linalg.norm(r_2,axis=1).reshape(-1,1)
norm_r2 = r_2/r2_norm

diff = r_1 - r_2
norm_diff = norm_r1 - norm_r2
distance = np.sqrt(np.sum(diff*diff, axis=1))
norm_dist = np.sqrt(np.sum(norm_diff*norm_diff, axis=1))

# %%
plt.plot(diff)
plt.show()
plt.plot(1/diff)
plt.show()

# %%
plt.plot(diff[210:215])
plt.title('electron distance')
plt.show()
plt.plot(data[210:215,-1])
plt.title('energy')
plt.show()
plt.plot(data[210:215,-2])
plt.title(r'$\alpha$')
plt.show()

# %%
plt.plot(diff[215:225])
plt.title('electron distance')
plt.show()
plt.plot(data[215:225,-1])
plt.title('energy')
plt.show()
plt.plot(data[215:220,-2])
plt.title(r'$\alpha$')
plt.show()

# %%
plt.plot(data[:,-1], label='energy')
plt.show()
plt.plot(data[:,-2], label=r'$\alpha$')
plt.show()
